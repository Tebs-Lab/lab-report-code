# %%
from matplotlib import pyplot as plt
import numpy as np

# evenly sampled time at 200ms intervals
x = np.arange(0., 50, 0.1)
y = 2*x + 400/x


plt.title("Zoomed Out")
plt.plot(x, y)
# Out:
# /var/folders/9z/z91mc8tn5j370jc8q1vspxn00000gn/T/ipykernel_3000/1993629657.py:6: RuntimeWarning: divide by zero encountered in divide
#   y = 2*x + 400/x

# %%
x_zoom = np.arange(4, 22, .01)
y_zoom = 2*x_zoom + 400/x_zoom

plt.title("Zoomed In To Critical Point")
plt.plot(x_zoom, y_zoom)
plt.scatter(14.14, 2*14.14 + 400 / 14.14, color='r')

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(12,6))

ax1.title.set_text("Zoomed Out")
ax1.plot(x, y)
ax1.scatter(14.14, 2*14.14 + 400 / 14.14, color='r')

ax2.title.set_text("Zoomed In To Critical Point")
ax2.plot( x_zoom, y_zoom)
ax2.scatter(14.14, 2*14.14 + 400 / 14.14, color='r')
